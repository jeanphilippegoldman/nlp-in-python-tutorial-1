# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# After the data cleaning step where we put our data into a few standard formats, the next step is to take a look at the data and see if what we're looking at makes sense. Before applying any fancy algorithms, it's always important to explore the data first.
#
# When working with numerical data, some of the exploratory data analysis (EDA) techniques we can use include finding the average of the data set, the distribution of the data, the most common values, etc. The idea is the same when working with text data. We are going to find some more obvious patterns with EDA before identifying the hidden patterns with machines learning (ML) techniques. We are going to look at the following for each comedian:
#
# 1. **Most common words** - find these and create word clouds
# 2. **Size of vocabulary** - look number of unique words and also how quickly someone speaks
# 3. **Amount of profanity** - most common terms

# %% [markdown]
# ## Most Common Words

# %% [markdown]
# ### Analysis

# %%
# Read in the document-term matrix
import pandas as pd

data = pd.read_pickle('dtm_fr.pkl')
data = data.transpose()
# data.head()
# Out:
#              Emmanuel Macron 2017  Emmanuel Macron 2018  Emmanuel Macron 2019  \
# abaisse                         0                     0                     0
# abandon                         0                     0                     0
# abandonnent                     0                     0                     0
# abandonner                      0                     0                     1
# abandonné                       0                     0                     1
#
#              Emmanuel Macron 2020  François Hollande 2012  \
# abaisse                         0                       0
# abandon                         0                       0
# abandonnent                     0                       0
# abandonner                      0                       0
# abandonné                       0                       0
#
#              François Hollande 2014  François Hollande 2015  \
# abaisse                           0                       0
# abandon                           1                       0
# abandonnent                       0                       0
# abandonner                        0                       0
# abandonné                         0                       0
#
#              François Hollande 2016  François Mitterrand 1981  \
# abaisse                           0                         0
# abandon                           0                         0
# abandonnent                       0                         0
# abandonner                        0                         0
# abandonné                         0                         0
#
#              François Mitterrand 1982  ...  Nicolas Sarkozy 2007  \
# abaisse                             0  ...                     0
# abandon                             0  ...                     0
# abandonnent                         0  ...                     0
# abandonner                          0  ...                     0
# abandonné                           0  ...                     0
#
#              Nicolas Sarkozy 2009  Nicolas Sarkozy 2010  Nicolas Sarkozy 2011  \
# abaisse                         0                     0                     0
# abandon                         0                     0                     0
# abandonnent                     0                     1                     0
# abandonner                      0                     0                     0
# abandonné                       0                     0                     0
#
#              Valéry Giscard d’Estaing 1974  Valéry Giscard d’Estaing 1975  \
# abaisse                                  0                              0
# abandon                                  0                              0
# abandonnent                              0                              0
# abandonner                               0                              0
# abandonné                                0                              0
#
#              Valéry Giscard d’Estaing 1977  Valéry Giscard d’Estaing 1978  \
# abaisse                                  0                              0
# abandon                                  0                              0
# abandonnent                              0                              0
# abandonner                               0                              0
# abandonné                                0                              0
#
#              Valéry Giscard d’Estaing 1979  Valéry Giscard d’Estaing 1980
# abaisse                                  0                              0
# abandon                                  0                              0
# abandonnent                              0                              0
# abandonner                               0                              0
# abandonné                                0                              0
#
# [5 rows x 43 columns]

# %%
# Find the top 30 words said by each comedian
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'Emmanuel Macron 2017': [('année', 16),
#   ('pays', 13),
#   ('besoin', 12),
#   ('travail', 12),
#   ('veux', 12),
#   ('nation', 7),
#   ('politique', 7),
#   ('france', 6),
#   ('engagement', 6),
#   ('règles', 6),
#   ('vie', 5),
#   ('sais', 5),
#   ('indispensable', 5),
#   ('hui', 5),
#   ('gouvernement', 5),
#   ('soir', 5),
#   ('retrouver', 5),
#   ('aujourd', 5),
#   ('mois', 5),
#   ('française', 5),
#   ('europe', 5),
#   ('leurs', 4),
#   ('celle', 4),
#   ('dire', 4),
#   ('davantage', 4),
#   ('toujours', 4),
#   ('continuerons', 4),
#   ('celui', 4),
#   ('chacune', 4),
#   ('grand', 4)],
#  'Emmanuel Macron 2018': [('pays', 9),
#   ('voeu', 8),
#   ('contre', 8),
#   ('année', 7),
#   ('travail', 7),
#   ('projet', 7),
#   ('crois', 7),
#   ('espoir', 7),
#   ('france', 7),
#   ('société', 6),
#   ('vie', 6),
#   ('mieux', 5),
#   ('européen', 5),
#   ('vivre', 5),
#   ('grandes', 5),
#   ('vérité', 5),
#   ('colère', 5),
#   ('sais', 5),
#   ('nouvelles', 5),
#   ('dignité', 4),
#   ('nombre', 4),
#   ('parfois', 4),
#   ('compatriotes', 4),
#   ('voulons', 4),
#   ('famille', 4),
#   ('profondément', 4),
#   ('avenir', 4),
#   ('partout', 4),
#   ('chers', 4),
#   ('monde', 4)],
#  'Emmanuel Macron 2019': [('france', 9),
#   ('décennie', 7),
#   ('travail', 7),
#   ('compatriotes', 6),
#   ('jour', 6),
#   ('pays', 6),
#   ('unité', 6),
#   ('année', 6),
#   ('contre', 6),
#   ('toujours', 5),
#   ('soir', 5),
#   ('français', 5),
#   ('beaucoup', 5),
#   ('sera', 5),
#   ('décisions', 5),
#   ('nouveaux', 5),
#   ('temps', 5),
#   ('nation', 5),
#   ('devons', 5),
#   ('progrès', 4),
#   ('vie', 4),
#   ('veux', 4),
#   ('nouvelle', 4),
#   ('écologique', 4),
#   ('enfants', 4),
#   ('chers', 4),
#   ('assurer', 4),
#   ('quelques', 4),
#   ('justice', 4),
#   ('dire', 4)],
#  'Emmanuel Macron 2020': [('année', 10),
#   ('espoir', 7),
#   ('france', 7),
#   ('autres', 7),
#   ('français', 6),
#   ('pays', 6),
#   ('beaucoup', 6),
#   ('lui', 6),
#   ('vies', 5),
#   ('vie', 5),
#   ('contre', 5),
#   ('soir', 5),
#   ('nation', 5),
#   ('tant', 4),
#   ('épidémie', 4),
#   ('quelques', 4),
#   ('ensemble', 4),
#   ('temps', 4),
#   ('mois', 4),
#   ('veux', 4),
#   ('printemps', 4),
#   ('permettre', 4),
#   ('compatriotes', 4),
#   ('quoi', 4),
#   ('forte', 4),
#   ('jours', 4),
#   ('européenne', 4),
#   ('europe', 4),
#   ('choix', 3),
#   ('virus', 3)],
#  'François Hollande 2012': [('france', 12),
#   ('sera', 9),
#   ('année', 5),
#   ('justice', 4),
#   ('seul', 3),
#   ('dès', 3),
#   ('demandé', 3),
#   ('compétitivité', 3),
#   ('avenir', 3),
#   ('pays', 3),
#   ('forces', 3),
#   ('veux', 3),
#   ('compris', 3),
#   ('confiance', 3),
#   ('peur', 3),
#   ('devoir', 3),
#   ('gouvernement', 3),
#   ('stabilité', 2),
#   ('vive', 2),
#   ('croissance', 2),
#   ('chers', 2),
#   ('ambition', 2),
#   ('travail', 2),
#   ('valeurs', 2),
#   ('etat', 2),
#   ('négociation', 2),
#   ('salariés', 2),
#   ('entreprises', 2),
#   ('devons', 2),
#   ('crise', 2)],
#  'François Hollande 2014': [('france', 17),
#   ('année', 11),
#   ('sera', 10),
#   ('confiance', 6),
#   ('contre', 6),
#   ('europe', 5),
#   ('loi', 5),
#   ('dire', 5),
#   ('pays', 5),
#   ('soit', 4),
#   ('entreprises', 4),
#   ('va', 4),
#   ('veux', 4),
#   ('chers', 4),
#   ('compatriotes', 4),
#   ('monde', 4),
#   ('soir', 4),
#   ('droits', 3),
#   ('conférence', 3),
#   ('enfants', 3),
#   ('personnes', 3),
#   ('demain', 3),
#   ('dès', 3),
#   ('face', 3),
#   ('chômage', 3),
#   ('jeunes', 3),
#   ('allais', 3),
#   ('mois', 3),
#   ('devons', 3),
#   ('planète', 3)],
#  'François Hollande 2015': [('france', 11),
#   ('contre', 6),
#   ('année', 5),
#   ('prendre', 4),
#   ('jamais', 4),
#   ('patrie', 4),
#   ('seront', 4),
#   ('compatriotes', 4),
#   ('français', 4),
#   ('face', 4),
#   ('urgence', 4),
#   ('attentats', 3),
#   ('aucun', 3),
#   ('besoin', 3),
#   ('protéger', 3),
#   ('europe', 3),
#   ('cet', 3),
#   ('république', 3),
#   ('soir', 3),
#   ('emploi', 3),
#   ('malgré', 2),
#   ('avenir', 2),
#   ('sécurité', 2),
#   ('soit', 2),
#   ('parlement', 2),
#   ('nouvelle', 2),
#   ('autant', 2),
#   ('paris', 2),
#   ('sera', 2),
#   ('adresse', 2)],
#  'François Hollande 2016': [('france', 13),
#   ('pays', 6),
#   ('face', 5),
#   ('liberté', 4),
#   ('va', 4),
#   ('surtout', 4),
#   ('veux', 4),
#   ('vie', 4),
#   ('chers', 4),
#   ('compatriotes', 4),
#   ('année', 3),
#   ('dernier', 3),
#   ('notamment', 3),
#   ('droits', 3),
#   ('république', 3),
#   ('choix', 3),
#   ('monde', 3),
#   ('santé', 2),
#   ('cinq', 2),
#   ('jusqu', 2),
#   ('origines', 2),
#   ('sécurité', 2),
#   ('capacité', 2),
#   ('contre', 2),
#   ('pense', 2),
#   ('acquis', 2),
#   ('partout', 2),
#   ('doute', 2),
#   ('cause', 2),
#   ('mandat', 2)],
#  'François Mitterrand 1981': [('france', 7),
#   ('année', 6),
#   ('droit', 5),
#   ('pays', 5),
#   ('avais', 5),
#   ('promis', 5),
#   ('ans', 4),
#   ('réforme', 4),
#   ('gouvernement', 3),
#   ('réformes', 3),
#   ('histoire', 3),
#   ('volonté', 3),
#   ('faudra', 3),
#   ('pouvoir', 3),
#   ('temps', 3),
#   ('bonne', 3),
#   ('français', 3),
#   ('sécurité', 3),
#   ('paix', 3),
#   ('politique', 3),
#   ('sera', 3),
#   ('dont', 3),
#   ('sait', 2),
#   ('vie', 2),
#   ('vive', 2),
#   ('celle', 2),
#   ('inflation', 2),
#   ('celles', 2),
#   ('condition', 2),
#   ('paris', 2)],
#  'François Mitterrand 1982': [('france', 6),
#   ('autres', 6),
#   ('monde', 5),
#   ('europe', 4),
#   ('bien', 4),
#   ('droits', 3),
#   ('produire', 3),
#   ('année', 3),
#   ('françaises', 3),
#   ('quiconque', 3),
#   ('moyens', 3),
#   ('français', 3),
#   ('soit', 3),
#   ('ans', 3),
#   ('ensemble', 3),
#   ('faut', 3),
#   ('politique', 3),
#   ('objectif', 3),
#   ('jeunes', 3),
#   ('gouvernement', 3),
#   ('formation', 2),
#   ('grand', 2),
#   ('pays', 2),
#   ('quoi', 2),
#   ('travail', 2),
#   ('sera', 2),
#   ('unis', 2),
#   ('marchés', 2),
#   ('ordre', 2),
#   ('travailleurs', 2)],
#  'François Mitterrand 1983': [('pense', 5),
#   ('année', 4),
#   ('ensemble', 4),
#   ('mieux', 3),
#   ('difficile', 3),
#   ('bien', 3),
#   ('bonne', 2),
#   ('chers', 2),
#   ('départements', 2),
#   ('soyons', 2),
#   ('statut', 2),
#   ('réformes', 2),
#   ('faut', 2),
#   ('environnement', 2),
#   ('place', 2),
#   ('revenons', 2),
#   ('compatriotes', 2),
#   ('crise', 2),
#   ('nouvelle', 2),
#   ('supporter', 2),
#   ('territoires', 2),
#   ('dit', 2),
#   ('loi', 2),
#   ('difficultés', 2),
#   ('pendant', 2),
#   ('adapter', 2),
#   ('vivre', 2),
#   ('enfants', 1),
#   ('apportée', 1),
#   ('régionale', 1)],
#  'François Mitterrand 1984': [('france', 6),
#   ('bonne', 5),
#   ('année', 5),
#   ('français', 4),
#   ('moi', 3),
#   ('europe', 3),
#   ('voeu', 3),
#   ('chers', 3),
#   ('dialogue', 3),
#   ('mêmes', 3),
#   ('compatriotes', 3),
#   ('bien', 3),
#   ('sera', 2),
#   ('aujourd', 2),
#   ('grands', 2),
#   ('patrie', 2),
#   ('tolérance', 2),
#   ('gagne', 2),
#   ('hui', 2),
#   ('parents', 2),
#   ('espoir', 2),
#   ('premier', 2),
#   ('union', 2),
#   ('petite', 2),
#   ('rien', 2),
#   ('jeunesse', 2),
#   ('vive', 2),
#   ('aimons', 2),
#   ('mission', 2),
#   ('chômage', 1)],
#  'François Mitterrand 1985': [('année', 6),
#   ('ans', 4),
#   ('bien', 3),
#   ('france', 3),
#   ('demandez', 3),
#   ('moi', 3),
#   ('cher', 3),
#   ('injustice', 3),
#   ('cinquième', 2),
#   ('étape', 2),
#   ('tant', 2),
#   ('peuple', 2),
#   ('vive', 2),
#   ('bonne', 2),
#   ('coûte', 2),
#   ('monde', 2),
#   ('vivre', 2),
#   ('puissance', 2),
#   ('heureuse', 2),
#   ('commence', 2),
#   ('courte', 2),
#   ('après', 2),
#   ('jour', 2),
#   ('travail', 2),
#   ('compatriotes', 2),
#   ('dire', 2),
#   ('chers', 2),
#   ('sera', 2),
#   ('instant', 1),
#   ('grave', 1)],
#  'François Mitterrand 1986': [('france', 7),
#   ('montré', 4),
#   ('vivre', 4),
#   ('politique', 4),
#   ('sache', 4),
#   ('contre', 3),
#   ('souhaite', 3),
#   ('mieux', 3),
#   ('année', 3),
#   ('défense', 3),
#   ('europe', 3),
#   ('faut', 3),
#   ('devions', 3),
#   ('démocratie', 3),
#   ('bonne', 3),
#   ('tant', 2),
#   ('monde', 2),
#   ('vois', 2),
#   ('vive', 2),
#   ('volonté', 2),
#   ('dangereuse', 2),
#   ('compatriotes', 2),
#   ('parviendra', 2),
#   ('vaut', 2),
#   ('inutile', 2),
#   ('chômage', 2),
#   ('autant', 2),
#   ('moyens', 2),
#   ('paix', 2),
#   ('unir', 2)],
#  'François Mitterrand 1987': [('france', 6),
#   ('rendez', 3),
#   ('paix', 3),
#   ('compatriotes', 3),
#   ('pays', 3),
#   ('ans', 3),
#   ('chers', 3),
#   ('politique', 2),
#   ('voeux', 2),
#   ('jour', 2),
#   ('république', 2),
#   ('vive', 2),
#   ('choix', 2),
#   ('souhaitons', 2),
#   ('année', 2),
#   ('sociale', 2),
#   ('peuple', 2),
#   ('voulu', 2),
#   ('sera', 2),
#   ('temps', 2),
#   ('fraternité', 2),
#   ('possible', 2),
#   ('jamais', 2),
#   ('europe', 2),
#   ('cinq', 2),
#   ('sente', 1),
#   ('exprimer', 1),
#   ('développés', 1),
#   ('prêtons', 1),
#   ('outre', 1)],
#  'François Mitterrand 1988': [('europe', 9),
#   ('strasbourg', 4),
#   ('me', 4),
#   ('pays', 3),
#   ('deux', 3),
#   ('france', 3),
#   ('risque', 3),
#   ('sera', 3),
#   ('chers', 3),
#   ('république', 3),
#   ('compatriotes', 3),
#   ('afin', 3),
#   ('français', 3),
#   ('nationale', 2),
#   ('bien', 2),
#   ('attends', 2),
#   ('politique', 2),
#   ('seule', 2),
#   ('mieux', 2),
#   ('vive', 2),
#   ('beaucoup', 2),
#   ('européen', 2),
#   ('nouvelle', 2),
#   ('ait', 2),
#   ('exemple', 2),
#   ('leurs', 2),
#   ('quatre', 2),
#   ('unis', 2),
#   ('année', 2),
#   ('dès', 2)],
#  'François Mitterrand 1989': [('liberté', 4),
#   ('forme', 4),
#   ('europe', 4),
#   ('pays', 4),
#   ('voeux', 4),
#   ('france', 4),
#   ('bien', 3),
#   ('deux', 3),
#   ('peuples', 3),
#   ('histoire', 3),
#   ('varsovie', 2),
#   ('sera', 2),
#   ('compatriotes', 2),
#   ('enfin', 2),
#   ('grands', 2),
#   ('ans', 2),
#   ('autres', 2),
#   ('vive', 2),
#   ('mêmes', 2),
#   ('année', 2),
#   ('auront', 2),
#   ('reste', 2),
#   ('chez', 2),
#   ('chers', 2),
#   ('contre', 2),
#   ('république', 2),
#   ('lois', 2),
#   ('millions', 2),
#   ('vers', 2),
#   ('régnait', 1)],
#  'François Mitterrand 1990': [('france', 9),
#   ('mieux', 6),
#   ('europe', 6),
#   ('pays', 4),
#   ('voeux', 4),
#   ('année', 3),
#   ('droit', 3),
#   ('mois', 3),
#   ('paix', 3),
#   ('sera', 3),
#   ('autres', 3),
#   ('guerre', 3),
#   ('reste', 3),
#   ('pourtant', 2),
#   ('inquiétude', 2),
#   ('place', 2),
#   ('compatriotes', 2),
#   ('signal', 2),
#   ('vie', 2),
#   ('seul', 2),
#   ('moi', 2),
#   ('grand', 2),
#   ('celle', 2),
#   ('république', 2),
#   ('général', 2),
#   ('monde', 2),
#   ('unis', 2),
#   ('gens', 2),
#   ('etats', 2),
#   ('jours', 2)],
#  'François Mitterrand 1991': [('france', 9),
#   ('mieux', 6),
#   ('europe', 6),
#   ('pays', 4),
#   ('voeux', 4),
#   ('année', 3),
#   ('droit', 3),
#   ('mois', 3),
#   ('paix', 3),
#   ('sera', 3),
#   ('autres', 3),
#   ('guerre', 3),
#   ('reste', 3),
#   ('pourtant', 2),
#   ('inquiétude', 2),
#   ('place', 2),
#   ('compatriotes', 2),
#   ('signal', 2),
#   ('vie', 2),
#   ('seul', 2),
#   ('moi', 2),
#   ('grand', 2),
#   ('celle', 2),
#   ('république', 2),
#   ('général', 2),
#   ('monde', 2),
#   ('unis', 2),
#   ('gens', 2),
#   ('etats', 2),
#   ('jours', 2)],
#  'François Mitterrand 1992': [('france', 5),
#   ('europe', 4),
#   ('celle', 3),
#   ('chers', 3),
#   ('compatriotes', 3),
#   ('intérêt', 3),
#   ('bosnie', 3),
#   ('année', 3),
#   ('sera', 3),
#   ('vive', 2),
#   ('bien', 2),
#   ('camps', 2),
#   ('demain', 2),
#   ('pays', 2),
#   ('grâce', 2),
#   ('unies', 2),
#   ('puisque', 2),
#   ('économique', 2),
#   ('vers', 2),
#   ('mois', 2),
#   ('meilleur', 2),
#   ('propositions', 2),
#   ('lui', 2),
#   ('communauté', 2),
#   ('sagesse', 2),
#   ('pouvoir', 2),
#   ('audace', 2),
#   ('cas', 2),
#   ('nations', 2),
#   ('place', 2)],
#  'François Mitterrand 1993': [('pays', 5),
#   ('dont', 4),
#   ('chers', 4),
#   ('aura', 4),
#   ('compatriotes', 4),
#   ('france', 3),
#   ('année', 3),
#   ('europe', 3),
#   ('paix', 3),
#   ('république', 3),
#   ('peuples', 3),
#   ('sociale', 3),
#   ('algérie', 2),
#   ('français', 2),
#   ('grand', 2),
#   ('douze', 2),
#   ('continent', 2),
#   ('après', 2),
#   ('fin', 2),
#   ('économique', 2),
#   ('sécurité', 2),
#   ('va', 2),
#   ('vive', 2),
#   ('chez', 2),
#   ('chômage', 2),
#   ('emploi', 2),
#   ('loin', 2),
#   ('autres', 2),
#   ('soldats', 2),
#   ('exemples', 2)],
#  'François Mitterrand 1994': [('france', 9),
#   ('année', 4),
#   ('vie', 4),
#   ('compatriotes', 4),
#   ('europe', 4),
#   ('chers', 4),
#   ('premier', 3),
#   ('eux', 3),
#   ('union', 3),
#   ('français', 3),
#   ('abord', 3),
#   ('ensemble', 3),
#   ('voeux', 3),
#   ('souffrent', 2),
#   ('travail', 2),
#   ('aura', 2),
#   ('véritable', 2),
#   ('plan', 2),
#   ('monde', 2),
#   ('prochain', 2),
#   ('forces', 2),
#   ('montrer', 2),
#   ('leurs', 2),
#   ('pouvoirs', 2),
#   ('mois', 2),
#   ('également', 2),
#   ('plein', 2),
#   ('nouvelle', 2),
#   ('souvent', 2),
#   ('autres', 2)],
#  'Jacques Chirac 1995': [('france', 11),
#   ('faut', 8),
#   ('pays', 7),
#   ('confiance', 7),
#   ('année', 7),
#   ('emploi', 6),
#   ('monde', 5),
#   ('adapter', 5),
#   ('bien', 4),
#   ('sera', 4),
#   ('face', 4),
#   ('français', 4),
#   ('sociale', 4),
#   ('devons', 4),
#   ('dont', 4),
#   ('celle', 3),
#   ('davantage', 3),
#   ('initiatives', 3),
#   ('ensemble', 3),
#   ('gouvernement', 3),
#   ('chômage', 3),
#   ('certains', 3),
#   ('souhaite', 3),
#   ('dépend', 3),
#   ('nom', 3),
#   ('leçon', 3),
#   ('mettre', 3),
#   ('chers', 3),
#   ('lutte', 3),
#   ('possible', 3)],
#  'Jacques Chirac 1996': [('france', 16),
#   ('jeunes', 7),
#   ('etat', 6),
#   ('faisons', 5),
#   ('année', 5),
#   ('français', 4),
#   ('pays', 4),
#   ('république', 3),
#   ('faut', 3),
#   ('construire', 3),
#   ('sera', 3),
#   ('forte', 3),
#   ('reculer', 3),
#   ('autrement', 3),
#   ('compatriotes', 3),
#   ('social', 3),
#   ('capable', 3),
#   ('violence', 3),
#   ('nation', 3),
#   ('apaisée', 3),
#   ('choix', 3),
#   ('réforme', 3),
#   ('accueillante', 3),
#   ('ensemble', 3),
#   ('dire', 3),
#   ('école', 3),
#   ('respect', 3),
#   ('dialogue', 3),
#   ('doivent', 2),
#   ('effort', 2)],
#  'Jacques Chirac 1997': [('france', 10),
#   ('cest', 7),
#   ('dire', 4),
#   ('avenir', 4),
#   ('temps', 4),
#   ('nest', 3),
#   ('français', 3),
#   ('sait', 3),
#   ('nouvelle', 3),
#   ('dentre', 3),
#   ('sera', 3),
#   ('premier', 3),
#   ('fais', 3),
#   ('nation', 3),
#   ('jamais', 3),
#   ('dautres', 3),
#   ('dêtre', 3),
#   ('année', 3),
#   ('bien', 3),
#   ('rassemblée', 3),
#   ('lon', 3),
#   ('créer', 3),
#   ('préserver', 2),
#   ('soyons', 2),
#   ('cet', 2),
#   ('française', 2),
#   ('sais', 2),
#   ('bonne', 2),
#   ('riches', 2),
#   ('comprendre', 2)],
#  'Jacques Chirac 1998': [('monde', 7),
#   ('bien', 7),
#   ('france', 6),
#   ('cest', 6),
#   ('ainsi', 5),
#   ('courage', 4),
#   ('nouvelles', 4),
#   ('ambition', 4),
#   ('compatriotes', 3),
#   ('sachons', 3),
#   ('solidarité', 3),
#   ('parfois', 3),
#   ('partout', 3),
#   ('changer', 3),
#   ('savons', 3),
#   ('leuro', 3),
#   ('soir', 3),
#   ('responsable', 3),
#   ('chers', 3),
#   ('marche', 3),
#   ('mondialisation', 2),
#   ('nouvelle', 2),
#   ('ouvert', 2),
#   ('notamment', 2),
#   ('chance', 2),
#   ('meilleur', 2),
#   ('chemin', 2),
#   ('sécurité', 2),
#   ('bonne', 2),
#   ('parmi', 2)],
#  'Jacques Chirac 1999': [('france', 7),
#   ('monde', 6),
#   ('siècle', 6),
#   ('progrès', 6),
#   ('avenir', 5),
#   ('bien', 5),
#   ('hommes', 4),
#   ('ensemble', 4),
#   ('solidarité', 4),
#   ('toujours', 3),
#   ('pense', 3),
#   ('chers', 3),
#   ('vie', 3),
#   ('sens', 3),
#   ('compatriotes', 3),
#   ('vivre', 3),
#   ('etat', 3),
#   ('dont', 3),
#   ('soir', 3),
#   ('part', 3),
#   ('mesurons', 3),
#   ('sécurité', 3),
#   ('homme', 3),
#   ('europe', 3),
#   ('enfants', 2),
#   ('moment', 2),
#   ('environnement', 2),
#   ('exigence', 2),
#   ('place', 2),
#   ('réussirons', 2)],
#  'Jacques Chirac 2001': [('europe', 10),
#   ('france', 9),
#   ('euro', 8),
#   ('solidarité', 7),
#   ('français', 7),
#   ('cohésion', 6),
#   ('etat', 6),
#   ('monde', 5),
#   ('république', 4),
#   ('choix', 4),
#   ('vivre', 4),
#   ('société', 4),
#   ('nationale', 4),
#   ('compatriotes', 4),
#   ('besoin', 3),
#   ('bien', 3),
#   ('chers', 3),
#   ('française', 3),
#   ('qualité', 3),
#   ('nation', 3),
#   ('voulez', 3),
#   ('charge', 3),
#   ('trouver', 2),
#   ('chacune', 2),
#   ('ambition', 2),
#   ('siècle', 2),
#   ('particulière', 2),
#   ('certains', 2),
#   ('épreuves', 2),
#   ('action', 2)],
#  'Jacques Chirac 2002': [('année', 8),
#   ('france', 7),
#   ('action', 6),
#   ('français', 6),
#   ('monde', 5),
#   ('sera', 5),
#   ('réformes', 4),
#   ('justice', 4),
#   ('solidarité', 4),
#   ('dont', 4),
#   ('effort', 3),
#   ('rassemblement', 3),
#   ('respect', 3),
#   ('nation', 3),
#   ('veux', 3),
#   ('compatriotes', 3),
#   ('beaucoup', 3),
#   ('confiance', 3),
#   ('intérêt', 3),
#   ('gouvernement', 3),
#   ('esprit', 3),
#   ('lucidité', 3),
#   ('responsabilité', 3),
#   ('chers', 3),
#   ('bien', 3),
#   ('bonne', 2),
#   ('volonté', 2),
#   ('pays', 2),
#   ('était', 2),
#   ('souvent', 2)],
#  'Jacques Chirac 2003': [('emploi', 11),
#   ('année', 8),
#   ('france', 7),
#   ('donner', 5),
#   ('mobiliser', 4),
#   ('devons', 4),
#   ('gouvernement', 4),
#   ('grâce', 4),
#   ('école', 4),
#   ('nouveaux', 4),
#   ('aujourd', 4),
#   ('hui', 4),
#   ('autres', 3),
#   ('celles', 3),
#   ('français', 3),
#   ('activité', 3),
#   ('système', 3),
#   ('entreprises', 3),
#   ('objectif', 3),
#   ('droit', 3),
#   ('salariés', 3),
#   ('moyens', 2),
#   ('heureuse', 2),
#   ('beaucoup', 2),
#   ('continuera', 2),
#   ('eux', 2),
#   ('bonne', 2),
#   ('également', 2),
#   ('grande', 2),
#   ('égalité', 2)],
#  'Jacques Chirac 2004': [('europe', 12),
#   ('croissance', 7),
#   ('société', 6),
#   ('france', 6),
#   ('emploi', 6),
#   ('avenir', 6),
#   ('compatriotes', 5),
#   ('veux', 5),
#   ('gouvernement', 5),
#   ('service', 4),
#   ('vers', 4),
#   ('première', 3),
#   ('soutien', 3),
#   ('moyens', 3),
#   ('dynamisme', 3),
#   ('chers', 3),
#   ('paix', 3),
#   ('nation', 3),
#   ('renforcer', 3),
#   ('temps', 3),
#   ('réforme', 3),
#   ('permettre', 3),
#   ('activité', 3),
#   ('place', 3),
#   ('action', 3),
#   ('nouvelle', 3),
#   ('année', 3),
#   ('celles', 3),
#   ('poursuivre', 3),
#   ('soir', 3)],
#  'Jacques Chirac 2005': [('république', 9),
#   ('france', 6),
#   ('europe', 6),
#   ('allons', 6),
#   ('compatriotes', 4),
#   ('contre', 4),
#   ('chers', 4),
#   ('mondialisation', 4),
#   ('avenir', 3),
#   ('emploi', 3),
#   ('faut', 3),
#   ('mois', 3),
#   ('année', 3),
#   ('partenaires', 3),
#   ('atout', 3),
#   ('mêmes', 3),
#   ('respect', 3),
#   ('action', 3),
#   ('projet', 3),
#   ('innovation', 2),
#   ('métropole', 2),
#   ('deux', 2),
#   ('pouvoir', 2),
#   ('croissance', 2),
#   ('outre', 2),
#   ('lutte', 2),
#   ('service', 2),
#   ('ouvrir', 2),
#   ('politique', 2),
#   ('après', 2)],
#  'Jacques Chirac 2006': [('france', 14),
#   ('monde', 7),
#   ('europe', 6),
#   ('enjeu', 6),
#   ('travail', 4),
#   ('vive', 4),
#   ('pays', 4),
#   ('premier', 3),
#   ('environnement', 3),
#   ('bien', 3),
#   ('respect', 3),
#   ('dire', 3),
#   ('victimes', 3),
#   ('social', 3),
#   ('grâce', 3),
#   ('exigence', 3),
#   ('paix', 3),
#   ('sécurité', 3),
#   ('place', 3),
#   ('gouvernement', 3),
#   ('avenir', 3),
#   ('chers', 2),
#   ('chômage', 2),
#   ('force', 2),
#   ('recherche', 2),
#   ('valeurs', 2),
#   ('comportements', 2),
#   ('garantie', 2),
#   ('chacune', 2),
#   ('vis', 2)],
#  'Nicolas Sarkozy 2007': [('france', 13),
#   ('urgence', 12),
#   ('vie', 8),
#   ('monde', 8),
#   ('année', 6),
#   ('pays', 5),
#   ('politique', 4),
#   ('autres', 4),
#   ('service', 4),
#   ('sais', 4),
#   ('français', 4),
#   ('pense', 4),
#   ('bien', 4),
#   ('nouvelle', 3),
#   ('dire', 3),
#   ('beaucoup', 3),
#   ('avenir', 3),
#   ('changement', 3),
#   ('pris', 3),
#   ('rôle', 3),
#   ('voulu', 3),
#   ('chers', 3),
#   ('malgré', 3),
#   ('sentiment', 3),
#   ('civilisation', 3),
#   ('toujours', 3),
#   ('davantage', 3),
#   ('attendent', 3),
#   ('vieux', 3),
#   ('veux', 3)],
#  'Nicolas Sarkozy 2009': [('compatriotes', 6),
#   ('année', 6),
#   ('france', 5),
#   ('avenir', 4),
#   ('chers', 4),
#   ('pays', 4),
#   ('sera', 4),
#   ('veux', 4),
#   ('grâce', 4),
#   ('organisation', 3),
#   ('justice', 3),
#   ('autres', 3),
#   ('soit', 3),
#   ('crise', 3),
#   ('pouvoir', 3),
#   ('davantage', 3),
#   ('bien', 3),
#   ('travail', 3),
#   ('aucun', 3),
#   ('face', 3),
#   ('mieux', 3),
#   ('permettre', 2),
#   ('dépenses', 2),
#   ('prendre', 2),
#   ('faisons', 2),
#   ('sens', 2),
#   ('enfin', 2),
#   ('soir', 2),
#   ('fiscalité', 2),
#   ('financière', 2)],
#  'Nicolas Sarkozy 2010': [('france', 9),
#   ('année', 8),
#   ('europe', 6),
#   ('chers', 6),
#   ('français', 5),
#   ('protéger', 5),
#   ('fin', 4),
#   ('compatriotes', 4),
#   ('respect', 4),
#   ('devoir', 3),
#   ('fut', 3),
#   ('bien', 3),
#   ('esprit', 3),
#   ('grâce', 3),
#   ('sera', 3),
#   ('crise', 3),
#   ('valeurs', 3),
#   ('service', 2),
#   ('serait', 2),
#   ('passé', 2),
#   ('pays', 2),
#   ('assez', 2),
#   ('leurs', 2),
#   ('ferai', 2),
#   ('protection', 2),
#   ('droit', 2),
#   ('façon', 2),
#   ('voeux', 2),
#   ('peine', 2),
#   ('mieux', 2)],
#  'Nicolas Sarkozy 2011': [('crise', 8),
#   ('france', 7),
#   ('économie', 6),
#   ('année', 6),
#   ('confiance', 5),
#   ('chers', 5),
#   ('grâce', 4),
#   ('devons', 4),
#   ('années', 4),
#   ('faut', 4),
#   ('compatriotes', 4),
#   ('pays', 4),
#   ('finance', 3),
#   ('question', 3),
#   ('celui', 3),
#   ('défis', 3),
#   ('préserver', 3),
#   ('monde', 3),
#   ('emploi', 3),
#   ('jusqu', 3),
#   ('difficultés', 3),
#   ('pouvoir', 3),
#   ('conséquences', 3),
#   ('pouvons', 3),
#   ('nouveau', 3),
#   ('travail', 3),
#   ('protection', 2),
#   ('doivent', 2),
#   ('propositions', 2),
#   ('nouvelle', 2)],
#  'Valéry Giscard d’Estaing 1974': [('annee', 22),
#   ('francais', 14),
#   ('france', 12),
#   ('voeux', 8),
#   ('dire', 7),
#   ('liberte', 7),
#   ('souhaite', 7),
#   ('francaise', 6),
#   ('monde', 6),
#   ('voudrais', 6),
#   ('pense', 5),
#   ('soir', 5),
#   ('problemes', 5),
#   ('fraternite', 5),
#   ('veut', 4),
#   ('dont', 4),
#   ('travail', 4),
#   ('vie', 4),
#   ('etre', 4),
#   ('societe', 4),
#   ('bien', 4),
#   ('certaines', 4),
#   ('categories', 4),
#   ('bonne', 4),
#   ('ete', 4),
#   ('quelques', 3),
#   ('adresser', 3),
#   ('leurs', 3),
#   ('mains', 3),
#   ('abord', 3)],
#  'Valéry Giscard d’Estaing 1975': [('france', 10),
#   ('francais', 7),
#   ('annee', 7),
#   ('voeux', 6),
#   ('souhaite', 5),
#   ('soit', 4),
#   ('rayonnement', 4),
#   ('unite', 3),
#   ('economie', 3),
#   ('dont', 3),
#   ('mieux', 3),
#   ('vie', 3),
#   ('etre', 3),
#   ('temps', 3),
#   ('leurs', 3),
#   ('bonne', 3),
#   ('bonheur', 3),
#   ('compatriotes', 3),
#   ('adressent', 3),
#   ('grandeur', 2),
#   ('dimension', 2),
#   ('nord', 2),
#   ('traverse', 2),
#   ('nom', 2),
#   ('cadre', 2),
#   ('veut', 2),
#   ('moderne', 2),
#   ('giscard', 2),
#   ('dis', 2),
#   ('fraternite', 2)],
#  'Valéry Giscard d’Estaing 1977': [('france', 11),
#   ('bonheur', 9),
#   ('souhaite', 5),
#   ('monde', 5),
#   ('sante', 4),
#   ('voeux', 4),
#   ('difficultes', 4),
#   ('meme', 4),
#   ('confiance', 4),
#   ('celle', 4),
#   ('annee', 3),
#   ('grande', 3),
#   ('unite', 3),
#   ('pensons', 3),
#   ('soir', 3),
#   ('lui', 3),
#   ('activite', 3),
#   ('lorsqu', 3),
#   ('competition', 3),
#   ('surmonter', 3),
#   ('francais', 3),
#   ('vrai', 3),
#   ('gars', 2),
#   ('ete', 2),
#   ('memes', 2),
#   ('toit', 2),
#   ('bonne', 2),
#   ('voulaient', 2),
#   ('vient', 2),
#   ('personnage', 2)],
#  'Valéry Giscard d’Estaing 1978': [('france', 11),
#   ('voeux', 6),
#   ('unite', 5),
#   ('francais', 4),
#   ('monde', 3),
#   ('crise', 3),
#   ('temps', 3),
#   ('bonheur', 3),
#   ('sera', 3),
#   ('sens', 3),
#   ('pays', 3),
#   ('autres', 2),
#   ('nations', 2),
#   ('enfants', 2),
#   ('succes', 2),
#   ('politique', 2),
#   ('dernier', 2),
#   ('trois', 2),
#   ('avenir', 2),
#   ('heureux', 2),
#   ('paix', 2),
#   ('concours', 2),
#   ('liberte', 2),
#   ('regions', 2),
#   ('sante', 2),
#   ('chacune', 2),
#   ('annees', 2),
#   ('souhaite', 2),
#   ('jours', 2),
#   ('soient', 2)],
#  'Valéry Giscard d’Estaing 1979': [('francais', 11),
#   ('france', 7),
#   ('voeux', 7),
#   ('meme', 4),
#   ('leurs', 4),
#   ('paix', 4),
#   ('pouvoir', 4),
#   ('republique', 4),
#   ('crise', 4),
#   ('petrole', 4),
#   ('augmente', 4),
#   ('unite', 4),
#   ('annee', 4),
#   ('achat', 4),
#   ('amis', 3),
#   ('quelques', 3),
#   ('periode', 3),
#   ('choc', 3),
#   ('nouveau', 3),
#   ('monde', 3),
#   ('soiree', 3),
#   ('ete', 3),
#   ('president', 3),
#   ('guerre', 3),
#   ('inegalites', 3),
#   ('allons', 3),
#   ('bien', 3),
#   ('bonne', 2),
#   ('telles', 2),
#   ('eux', 2)],
#  'Valéry Giscard d’Estaing 1980': [('france', 10),
#   ('pays', 10),
#   ('année', 10),
#   ('monde', 8),
#   ('confiance', 5),
#   ('liberté', 5),
#   ('français', 4),
#   ('libertés', 4),
#   ('bien', 4),
#   ('choses', 3),
#   ('république', 3),
#   ('signes', 3),
#   ('françaises', 3),
#   ('moment', 3),
#   ('progrès', 3),
#   ('autant', 3),
#   ('grand', 3),
#   ('deux', 3),
#   ('indépendance', 2),
#   ('sera', 2),
#   ('difficile', 2),
#   ('compter', 2),
#   ('difficultés', 2),
#   ('paix', 2),
#   ('veut', 2),
#   ('lois', 2),
#   ('société', 2),
#   ('rang', 2),
#   ('faut', 2),
#   ('force', 2)]}

# %%
# Print the top 15 words said by each comedian
for comedian, top_words in top_dict.items():
    print(comedian)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# Emmanuel Macron 2017
# année, pays, besoin, travail, veux, nation, politique, france, engagement, règles, vie, sais, indispensable, hui
# ---
# Emmanuel Macron 2018
# pays, voeu, contre, année, travail, projet, crois, espoir, france, société, vie, mieux, européen, vivre
# ---
# Emmanuel Macron 2019
# france, décennie, travail, compatriotes, jour, pays, unité, année, contre, toujours, soir, français, beaucoup, sera
# ---
# Emmanuel Macron 2020
# année, espoir, france, autres, français, pays, beaucoup, lui, vies, vie, contre, soir, nation, tant
# ---
# François Hollande 2012
# france, sera, année, justice, seul, dès, demandé, compétitivité, avenir, pays, forces, veux, compris, confiance
# ---
# François Hollande 2014
# france, année, sera, confiance, contre, europe, loi, dire, pays, soit, entreprises, va, veux, chers
# ---
# François Hollande 2015
# france, contre, année, prendre, jamais, patrie, seront, compatriotes, français, face, urgence, attentats, aucun, besoin
# ---
# François Hollande 2016
# france, pays, face, liberté, va, surtout, veux, vie, chers, compatriotes, année, dernier, notamment, droits
# ---
# François Mitterrand 1981
# france, année, droit, pays, avais, promis, ans, réforme, gouvernement, réformes, histoire, volonté, faudra, pouvoir
# ---
# François Mitterrand 1982
# france, autres, monde, europe, bien, droits, produire, année, françaises, quiconque, moyens, français, soit, ans
# ---
# François Mitterrand 1983
# pense, année, ensemble, mieux, difficile, bien, bonne, chers, départements, soyons, statut, réformes, faut, environnement
# ---
# François Mitterrand 1984
# france, bonne, année, français, moi, europe, voeu, chers, dialogue, mêmes, compatriotes, bien, sera, aujourd
# ---
# François Mitterrand 1985
# année, ans, bien, france, demandez, moi, cher, injustice, cinquième, étape, tant, peuple, vive, bonne
# ---
# François Mitterrand 1986
# france, montré, vivre, politique, sache, contre, souhaite, mieux, année, défense, europe, faut, devions, démocratie
# ---
# François Mitterrand 1987
# france, rendez, paix, compatriotes, pays, ans, chers, politique, voeux, jour, république, vive, choix, souhaitons
# ---
# François Mitterrand 1988
# europe, strasbourg, me, pays, deux, france, risque, sera, chers, république, compatriotes, afin, français, nationale
# ---
# François Mitterrand 1989
# liberté, forme, europe, pays, voeux, france, bien, deux, peuples, histoire, varsovie, sera, compatriotes, enfin
# ---
# François Mitterrand 1990
# france, mieux, europe, pays, voeux, année, droit, mois, paix, sera, autres, guerre, reste, pourtant
# ---
# François Mitterrand 1991
# france, mieux, europe, pays, voeux, année, droit, mois, paix, sera, autres, guerre, reste, pourtant
# ---
# François Mitterrand 1992
# france, europe, celle, chers, compatriotes, intérêt, bosnie, année, sera, vive, bien, camps, demain, pays
# ---
# François Mitterrand 1993
# pays, dont, chers, aura, compatriotes, france, année, europe, paix, république, peuples, sociale, algérie, français
# ---
# François Mitterrand 1994
# france, année, vie, compatriotes, europe, chers, premier, eux, union, français, abord, ensemble, voeux, souffrent
# ---
# Jacques Chirac 1995
# france, faut, pays, confiance, année, emploi, monde, adapter, bien, sera, face, français, sociale, devons
# ---
# Jacques Chirac 1996
# france, jeunes, etat, faisons, année, français, pays, république, faut, construire, sera, forte, reculer, autrement
# ---
# Jacques Chirac 1997
# france, cest, dire, avenir, temps, nest, français, sait, nouvelle, dentre, sera, premier, fais, nation
# ---
# Jacques Chirac 1998
# monde, bien, france, cest, ainsi, courage, nouvelles, ambition, compatriotes, sachons, solidarité, parfois, partout, changer
# ---
# Jacques Chirac 1999
# france, monde, siècle, progrès, avenir, bien, hommes, ensemble, solidarité, toujours, pense, chers, vie, sens
# ---
# Jacques Chirac 2001
# europe, france, euro, solidarité, français, cohésion, etat, monde, république, choix, vivre, société, nationale, compatriotes
# ---
# Jacques Chirac 2002
# année, france, action, français, monde, sera, réformes, justice, solidarité, dont, effort, rassemblement, respect, nation
# ---
# Jacques Chirac 2003
# emploi, année, france, donner, mobiliser, devons, gouvernement, grâce, école, nouveaux, aujourd, hui, autres, celles
# ---
# Jacques Chirac 2004
# europe, croissance, société, france, emploi, avenir, compatriotes, veux, gouvernement, service, vers, première, soutien, moyens
# ---
# Jacques Chirac 2005
# république, france, europe, allons, compatriotes, contre, chers, mondialisation, avenir, emploi, faut, mois, année, partenaires
# ---
# Jacques Chirac 2006
# france, monde, europe, enjeu, travail, vive, pays, premier, environnement, bien, respect, dire, victimes, social
# ---
# Nicolas Sarkozy 2007
# france, urgence, vie, monde, année, pays, politique, autres, service, sais, français, pense, bien, nouvelle
# ---
# Nicolas Sarkozy 2009
# compatriotes, année, france, avenir, chers, pays, sera, veux, grâce, organisation, justice, autres, soit, crise
# ---
# Nicolas Sarkozy 2010
# france, année, europe, chers, français, protéger, fin, compatriotes, respect, devoir, fut, bien, esprit, grâce
# ---
# Nicolas Sarkozy 2011
# crise, france, économie, année, confiance, chers, grâce, devons, années, faut, compatriotes, pays, finance, question
# ---
# Valéry Giscard d’Estaing 1974
# annee, francais, france, voeux, dire, liberte, souhaite, francaise, monde, voudrais, pense, soir, problemes, fraternite
# ---
# Valéry Giscard d’Estaing 1975
# france, francais, annee, voeux, souhaite, soit, rayonnement, unite, economie, dont, mieux, vie, etre, temps
# ---
# Valéry Giscard d’Estaing 1977
# france, bonheur, souhaite, monde, sante, voeux, difficultes, meme, confiance, celle, annee, grande, unite, pensons
# ---
# Valéry Giscard d’Estaing 1978
# france, voeux, unite, francais, monde, crise, temps, bonheur, sera, sens, pays, autres, nations, enfants
# ---
# Valéry Giscard d’Estaing 1979
# francais, france, voeux, meme, leurs, paix, pouvoir, republique, crise, petrole, augmente, unite, annee, achat
# ---
# Valéry Giscard d’Estaing 1980
# france, pays, année, monde, confiance, liberté, français, libertés, bien, choses, république, signes, françaises, moment
# ---

# %% [markdown]
# **NOTE:** At this point, we could go on and create word clouds. However, by looking at these top words, you can see that some of them have very little meaning and could be added to a stop words list, so let's do just that.

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each comedian
words = []
for comedian in data.columns:
    top = [word for (word, count) in top_dict[comedian]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['année',
#  'pays',
#  'besoin',
#  'travail',
#  'veux',
#  'nation',
#  'politique',
#  'france',
#  'engagement',
#  'règles',
#  'vie',
#  'sais',
#  'indispensable',
#  'hui',
#  'gouvernement',
#  'soir',
#  'retrouver',
#  'aujourd',
#  'mois',
#  'française',
#  'europe',
#  'leurs',
#  'celle',
#  'dire',
#  'davantage',
#  'toujours',
#  'continuerons',
#  'celui',
#  'chacune',
#  'grand',
#  'pays',
#  'voeu',
#  'contre',
#  'année',
#  'travail',
#  'projet',
#  'crois',
#  'espoir',
#  'france',
#  'société',
#  'vie',
#  'mieux',
#  'européen',
#  'vivre',
#  'grandes',
#  'vérité',
#  'colère',
#  'sais',
#  'nouvelles',
#  'dignité',
#  'nombre',
#  'parfois',
#  'compatriotes',
#  'voulons',
#  'famille',
#  'profondément',
#  'avenir',
#  'partout',
#  'chers',
#  'monde',
#  'france',
#  'décennie',
#  'travail',
#  'compatriotes',
#  'jour',
#  'pays',
#  'unité',
#  'année',
#  'contre',
#  'toujours',
#  'soir',
#  'français',
#  'beaucoup',
#  'sera',
#  'décisions',
#  'nouveaux',
#  'temps',
#  'nation',
#  'devons',
#  'progrès',
#  'vie',
#  'veux',
#  'nouvelle',
#  'écologique',
#  'enfants',
#  'chers',
#  'assurer',
#  'quelques',
#  'justice',
#  'dire',
#  'année',
#  'espoir',
#  'france',
#  'autres',
#  'français',
#  'pays',
#  'beaucoup',
#  'lui',
#  'vies',
#  'vie',
#  'contre',
#  'soir',
#  'nation',
#  'tant',
#  'épidémie',
#  'quelques',
#  'ensemble',
#  'temps',
#  'mois',
#  'veux',
#  'printemps',
#  'permettre',
#  'compatriotes',
#  'quoi',
#  'forte',
#  'jours',
#  'européenne',
#  'europe',
#  'choix',
#  'virus',
#  'france',
#  'sera',
#  'année',
#  'justice',
#  'seul',
#  'dès',
#  'demandé',
#  'compétitivité',
#  'avenir',
#  'pays',
#  'forces',
#  'veux',
#  'compris',
#  'confiance',
#  'peur',
#  'devoir',
#  'gouvernement',
#  'stabilité',
#  'vive',
#  'croissance',
#  'chers',
#  'ambition',
#  'travail',
#  'valeurs',
#  'etat',
#  'négociation',
#  'salariés',
#  'entreprises',
#  'devons',
#  'crise',
#  'france',
#  'année',
#  'sera',
#  'confiance',
#  'contre',
#  'europe',
#  'loi',
#  'dire',
#  'pays',
#  'soit',
#  'entreprises',
#  'va',
#  'veux',
#  'chers',
#  'compatriotes',
#  'monde',
#  'soir',
#  'droits',
#  'conférence',
#  'enfants',
#  'personnes',
#  'demain',
#  'dès',
#  'face',
#  'chômage',
#  'jeunes',
#  'allais',
#  'mois',
#  'devons',
#  'planète',
#  'france',
#  'contre',
#  'année',
#  'prendre',
#  'jamais',
#  'patrie',
#  'seront',
#  'compatriotes',
#  'français',
#  'face',
#  'urgence',
#  'attentats',
#  'aucun',
#  'besoin',
#  'protéger',
#  'europe',
#  'cet',
#  'république',
#  'soir',
#  'emploi',
#  'malgré',
#  'avenir',
#  'sécurité',
#  'soit',
#  'parlement',
#  'nouvelle',
#  'autant',
#  'paris',
#  'sera',
#  'adresse',
#  'france',
#  'pays',
#  'face',
#  'liberté',
#  'va',
#  'surtout',
#  'veux',
#  'vie',
#  'chers',
#  'compatriotes',
#  'année',
#  'dernier',
#  'notamment',
#  'droits',
#  'république',
#  'choix',
#  'monde',
#  'santé',
#  'cinq',
#  'jusqu',
#  'origines',
#  'sécurité',
#  'capacité',
#  'contre',
#  'pense',
#  'acquis',
#  'partout',
#  'doute',
#  'cause',
#  'mandat',
#  'france',
#  'année',
#  'droit',
#  'pays',
#  'avais',
#  'promis',
#  'ans',
#  'réforme',
#  'gouvernement',
#  'réformes',
#  'histoire',
#  'volonté',
#  'faudra',
#  'pouvoir',
#  'temps',
#  'bonne',
#  'français',
#  'sécurité',
#  'paix',
#  'politique',
#  'sera',
#  'dont',
#  'sait',
#  'vie',
#  'vive',
#  'celle',
#  'inflation',
#  'celles',
#  'condition',
#  'paris',
#  'france',
#  'autres',
#  'monde',
#  'europe',
#  'bien',
#  'droits',
#  'produire',
#  'année',
#  'françaises',
#  'quiconque',
#  'moyens',
#  'français',
#  'soit',
#  'ans',
#  'ensemble',
#  'faut',
#  'politique',
#  'objectif',
#  'jeunes',
#  'gouvernement',
#  'formation',
#  'grand',
#  'pays',
#  'quoi',
#  'travail',
#  'sera',
#  'unis',
#  'marchés',
#  'ordre',
#  'travailleurs',
#  'pense',
#  'année',
#  'ensemble',
#  'mieux',
#  'difficile',
#  'bien',
#  'bonne',
#  'chers',
#  'départements',
#  'soyons',
#  'statut',
#  'réformes',
#  'faut',
#  'environnement',
#  'place',
#  'revenons',
#  'compatriotes',
#  'crise',
#  'nouvelle',
#  'supporter',
#  'territoires',
#  'dit',
#  'loi',
#  'difficultés',
#  'pendant',
#  'adapter',
#  'vivre',
#  'enfants',
#  'apportée',
#  'régionale',
#  'france',
#  'bonne',
#  'année',
#  'français',
#  'moi',
#  'europe',
#  'voeu',
#  'chers',
#  'dialogue',
#  'mêmes',
#  'compatriotes',
#  'bien',
#  'sera',
#  'aujourd',
#  'grands',
#  'patrie',
#  'tolérance',
#  'gagne',
#  'hui',
#  'parents',
#  'espoir',
#  'premier',
#  'union',
#  'petite',
#  'rien',
#  'jeunesse',
#  'vive',
#  'aimons',
#  'mission',
#  'chômage',
#  'année',
#  'ans',
#  'bien',
#  'france',
#  'demandez',
#  'moi',
#  'cher',
#  'injustice',
#  'cinquième',
#  'étape',
#  'tant',
#  'peuple',
#  'vive',
#  'bonne',
#  'coûte',
#  'monde',
#  'vivre',
#  'puissance',
#  'heureuse',
#  'commence',
#  'courte',
#  'après',
#  'jour',
#  'travail',
#  'compatriotes',
#  'dire',
#  'chers',
#  'sera',
#  'instant',
#  'grave',
#  'france',
#  'montré',
#  'vivre',
#  'politique',
#  'sache',
#  'contre',
#  'souhaite',
#  'mieux',
#  'année',
#  'défense',
#  'europe',
#  'faut',
#  'devions',
#  'démocratie',
#  'bonne',
#  'tant',
#  'monde',
#  'vois',
#  'vive',
#  'volonté',
#  'dangereuse',
#  'compatriotes',
#  'parviendra',
#  'vaut',
#  'inutile',
#  'chômage',
#  'autant',
#  'moyens',
#  'paix',
#  'unir',
#  'france',
#  'rendez',
#  'paix',
#  'compatriotes',
#  'pays',
#  'ans',
#  'chers',
#  'politique',
#  'voeux',
#  'jour',
#  'république',
#  'vive',
#  'choix',
#  'souhaitons',
#  'année',
#  'sociale',
#  'peuple',
#  'voulu',
#  'sera',
#  'temps',
#  'fraternité',
#  'possible',
#  'jamais',
#  'europe',
#  'cinq',
#  'sente',
#  'exprimer',
#  'développés',
#  'prêtons',
#  'outre',
#  'europe',
#  'strasbourg',
#  'me',
#  'pays',
#  'deux',
#  'france',
#  'risque',
#  'sera',
#  'chers',
#  'république',
#  'compatriotes',
#  'afin',
#  'français',
#  'nationale',
#  'bien',
#  'attends',
#  'politique',
#  'seule',
#  'mieux',
#  'vive',
#  'beaucoup',
#  'européen',
#  'nouvelle',
#  'ait',
#  'exemple',
#  'leurs',
#  'quatre',
#  'unis',
#  'année',
#  'dès',
#  'liberté',
#  'forme',
#  'europe',
#  'pays',
#  'voeux',
#  'france',
#  'bien',
#  'deux',
#  'peuples',
#  'histoire',
#  'varsovie',
#  'sera',
#  'compatriotes',
#  'enfin',
#  'grands',
#  'ans',
#  'autres',
#  'vive',
#  'mêmes',
#  'année',
#  'auront',
#  'reste',
#  'chez',
#  'chers',
#  'contre',
#  'république',
#  'lois',
#  'millions',
#  'vers',
#  'régnait',
#  'france',
#  'mieux',
#  'europe',
#  'pays',
#  'voeux',
#  'année',
#  'droit',
#  'mois',
#  'paix',
#  'sera',
#  'autres',
#  'guerre',
#  'reste',
#  'pourtant',
#  'inquiétude',
#  'place',
#  'compatriotes',
#  'signal',
#  'vie',
#  'seul',
#  'moi',
#  'grand',
#  'celle',
#  'république',
#  'général',
#  'monde',
#  'unis',
#  'gens',
#  'etats',
#  'jours',
#  'france',
#  'mieux',
#  'europe',
#  'pays',
#  'voeux',
#  'année',
#  'droit',
#  'mois',
#  'paix',
#  'sera',
#  'autres',
#  'guerre',
#  'reste',
#  'pourtant',
#  'inquiétude',
#  'place',
#  'compatriotes',
#  'signal',
#  'vie',
#  'seul',
#  'moi',
#  'grand',
#  'celle',
#  'république',
#  'général',
#  'monde',
#  'unis',
#  'gens',
#  'etats',
#  'jours',
#  'france',
#  'europe',
#  'celle',
#  'chers',
#  'compatriotes',
#  'intérêt',
#  'bosnie',
#  'année',
#  'sera',
#  'vive',
#  'bien',
#  'camps',
#  'demain',
#  'pays',
#  'grâce',
#  'unies',
#  'puisque',
#  'économique',
#  'vers',
#  'mois',
#  'meilleur',
#  'propositions',
#  'lui',
#  'communauté',
#  'sagesse',
#  'pouvoir',
#  'audace',
#  'cas',
#  'nations',
#  'place',
#  'pays',
#  'dont',
#  'chers',
#  'aura',
#  'compatriotes',
#  'france',
#  'année',
#  'europe',
#  'paix',
#  'république',
#  'peuples',
#  'sociale',
#  'algérie',
#  'français',
#  'grand',
#  'douze',
#  'continent',
#  'après',
#  'fin',
#  'économique',
#  'sécurité',
#  'va',
#  'vive',
#  'chez',
#  'chômage',
#  'emploi',
#  'loin',
#  'autres',
#  'soldats',
#  'exemples',
#  'france',
#  'année',
#  'vie',
#  'compatriotes',
#  'europe',
#  'chers',
#  'premier',
#  'eux',
#  'union',
#  'français',
#  'abord',
#  'ensemble',
#  'voeux',
#  'souffrent',
#  'travail',
#  'aura',
#  'véritable',
#  'plan',
#  'monde',
#  'prochain',
#  'forces',
#  'montrer',
#  'leurs',
#  'pouvoirs',
#  'mois',
#  'également',
#  'plein',
#  'nouvelle',
#  'souvent',
#  'autres',
#  'france',
#  'faut',
#  'pays',
#  'confiance',
#  'année',
#  'emploi',
#  'monde',
#  'adapter',
#  'bien',
#  'sera',
#  'face',
#  'français',
#  'sociale',
#  'devons',
#  'dont',
#  'celle',
#  'davantage',
#  'initiatives',
#  'ensemble',
#  'gouvernement',
#  'chômage',
#  'certains',
#  'souhaite',
#  'dépend',
#  'nom',
#  'leçon',
#  'mettre',
#  'chers',
#  'lutte',
#  'possible',
#  'france',
#  'jeunes',
#  'etat',
#  'faisons',
#  'année',
#  'français',
#  'pays',
#  'république',
#  'faut',
#  'construire',
#  'sera',
#  'forte',
#  'reculer',
#  'autrement',
#  'compatriotes',
#  'social',
#  'capable',
#  'violence',
#  'nation',
#  'apaisée',
#  'choix',
#  'réforme',
#  'accueillante',
#  'ensemble',
#  'dire',
#  'école',
#  'respect',
#  'dialogue',
#  'doivent',
#  'effort',
#  'france',
#  'cest',
#  'dire',
#  'avenir',
#  'temps',
#  'nest',
#  'français',
#  'sait',
#  'nouvelle',
#  'dentre',
#  'sera',
#  'premier',
#  'fais',
#  'nation',
#  'jamais',
#  'dautres',
#  'dêtre',
#  'année',
#  'bien',
#  'rassemblée',
#  'lon',
#  'créer',
#  'préserver',
#  'soyons',
#  'cet',
#  'française',
#  'sais',
#  'bonne',
#  'riches',
#  'comprendre',
#  'monde',
#  'bien',
#  'france',
#  'cest',
#  'ainsi',
#  'courage',
#  'nouvelles',
#  'ambition',
#  'compatriotes',
#  'sachons',
#  'solidarité',
#  'parfois',
#  'partout',
#  'changer',
#  'savons',
#  'leuro',
#  'soir',
#  'responsable',
#  'chers',
#  'marche',
#  'mondialisation',
#  'nouvelle',
#  'ouvert',
#  'notamment',
#  'chance',
#  'meilleur',
#  'chemin',
#  'sécurité',
#  'bonne',
#  'parmi',
#  'france',
#  'monde',
#  'siècle',
#  'progrès',
#  'avenir',
#  'bien',
#  'hommes',
#  'ensemble',
#  'solidarité',
#  'toujours',
#  'pense',
#  'chers',
#  'vie',
#  'sens',
#  'compatriotes',
#  'vivre',
#  'etat',
#  'dont',
#  'soir',
#  'part',
#  'mesurons',
#  'sécurité',
#  'homme',
#  'europe',
#  'enfants',
#  'moment',
#  'environnement',
#  'exigence',
#  'place',
#  'réussirons',
#  'europe',
#  'france',
#  'euro',
#  'solidarité',
#  'français',
#  'cohésion',
#  'etat',
#  'monde',
#  'république',
#  'choix',
#  'vivre',
#  'société',
#  'nationale',
#  'compatriotes',
#  'besoin',
#  'bien',
#  'chers',
#  'française',
#  'qualité',
#  'nation',
#  'voulez',
#  'charge',
#  'trouver',
#  'chacune',
#  'ambition',
#  'siècle',
#  'particulière',
#  'certains',
#  'épreuves',
#  'action',
#  'année',
#  'france',
#  'action',
#  'français',
#  'monde',
#  'sera',
#  'réformes',
#  'justice',
#  'solidarité',
#  'dont',
#  'effort',
#  'rassemblement',
#  'respect',
#  'nation',
#  'veux',
#  'compatriotes',
#  'beaucoup',
#  'confiance',
#  'intérêt',
#  'gouvernement',
#  'esprit',
#  'lucidité',
#  'responsabilité',
#  'chers',
#  'bien',
#  'bonne',
#  'volonté',
#  'pays',
#  'était',
#  'souvent',
#  'emploi',
#  'année',
#  'france',
#  'donner',
#  'mobiliser',
#  'devons',
#  'gouvernement',
#  'grâce',
#  'école',
#  'nouveaux',
#  'aujourd',
#  'hui',
#  'autres',
#  'celles',
#  'français',
#  'activité',
#  'système',
#  'entreprises',
#  'objectif',
#  'droit',
#  'salariés',
#  'moyens',
#  'heureuse',
#  'beaucoup',
#  'continuera',
#  'eux',
#  'bonne',
#  'également',
#  'grande',
#  'égalité',
#  'europe',
#  'croissance',
#  'société',
#  'france',
#  'emploi',
#  'avenir',
#  'compatriotes',
#  'veux',
#  'gouvernement',
#  'service',
#  'vers',
#  'première',
#  'soutien',
#  'moyens',
#  'dynamisme',
#  'chers',
#  'paix',
#  'nation',
#  'renforcer',
#  'temps',
#  'réforme',
#  'permettre',
#  'activité',
#  'place',
#  'action',
#  'nouvelle',
#  'année',
#  'celles',
#  'poursuivre',
#  'soir',
#  'république',
#  'france',
#  'europe',
#  'allons',
#  'compatriotes',
#  'contre',
#  'chers',
#  'mondialisation',
#  'avenir',
#  'emploi',
#  'faut',
#  'mois',
#  'année',
#  'partenaires',
#  'atout',
#  'mêmes',
#  'respect',
#  'action',
#  'projet',
#  'innovation',
#  'métropole',
#  'deux',
#  'pouvoir',
#  'croissance',
#  'outre',
#  'lutte',
#  'service',
#  'ouvrir',
#  'politique',
#  'après',
#  'france',
#  'monde',
#  'europe',
#  'enjeu',
#  'travail',
#  'vive',
#  'pays',
#  'premier',
#  'environnement',
#  'bien',
#  'respect',
#  'dire',
#  'victimes',
#  'social',
#  'grâce',
#  'exigence',
#  'paix',
#  'sécurité',
#  'place',
#  'gouvernement',
#  'avenir',
#  'chers',
#  'chômage',
#  'force',
#  'recherche',
#  'valeurs',
#  'comportements',
#  'garantie',
#  'chacune',
#  'vis',
#  'france',
#  'urgence',
#  'vie',
#  'monde',
#  'année',
#  'pays',
#  'politique',
#  'autres',
#  'service',
#  'sais',
#  ...]

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('france', 42),
#  ('année', 34),
#  ('compatriotes', 29),
#  ('pays', 26),
#  ('chers', 26),
#  ('monde', 22),
#  ('sera', 22),
#  ('europe', 21),
#  ('bien', 20),
#  ('français', 18),
#  ('vie', 13),
#  ('bonne', 13),
#  ('république', 12),
#  ('travail', 11),
#  ('soir', 11),
#  ('avenir', 11),
#  ('autres', 11),
#  ('vive', 11),
#  ('paix', 11),
#  ('voeux', 11),
#  ('veux', 10),
#  ('nouvelle', 10),
#  ('politique', 9),
#  ('gouvernement', 9),
#  ('dire', 9),
#  ('contre', 9),
#  ('mieux', 9),
#  ('nation', 8),
#  ('mois', 8),
#  ('temps', 8),
#  ('faut', 8),
#  ('leurs', 7),
#  ('celle', 7),
#  ('ensemble', 7),
#  ('confiance', 7),
#  ('crise', 7),
#  ('emploi', 7),
#  ('sécurité', 7),
#  ('dont', 7),
#  ('place', 7),
#  ('grand', 6),
#  ('vivre', 6),
#  ('beaucoup', 6),
#  ('devons', 6),
#  ('chômage', 6),
#  ('pouvoir', 6),
#  ('souhaite', 6),
#  ('grâce', 6),
#  ('enfants', 5),
#  ('choix', 5),
#  ('soit', 5),
#  ('face', 5),
#  ('pense', 5),
#  ('droit', 5),
#  ('ans', 5),
#  ('respect', 5),
#  ('francais', 5),
#  ('sais', 4),
#  ('davantage', 4),
#  ('toujours', 4),
#  ('chacune', 4),
#  ('société', 4),
#  ('quelques', 4),
#  ('justice', 4),
#  ('jours', 4),
#  ('etat', 4),
#  ('moyens', 4),
#  ('unis', 4),
#  ('moi', 4),
#  ('premier', 4),
#  ('deux', 4),
#  ('solidarité', 4),
#  ('action', 4),
#  ('service', 4),
#  ('annee', 4),
#  ('unite', 4),
#  ('besoin', 3),
#  ('hui', 3),
#  ('aujourd', 3),
#  ('française', 3),
#  ('espoir', 3),
#  ('partout', 3),
#  ('jour', 3),
#  ('progrès', 3),
#  ('lui', 3),
#  ('tant', 3),
#  ('permettre', 3),
#  ('seul', 3),
#  ('dès', 3),
#  ('croissance', 3),
#  ('ambition', 3),
#  ('valeurs', 3),
#  ('entreprises', 3),
#  ('va', 3),
#  ('droits', 3),
#  ('jeunes', 3),
#  ('jamais', 3),
#  ('autant', 3),
#  ('liberté', 3),
#  ('réforme', 3),
#  ('réformes', 3),
#  ('volonté', 3),
#  ('celles', 3),
#  ('environnement', 3),
#  ('difficultés', 3),
#  ('mêmes', 3),
#  ('après', 3),
#  ('sociale', 3),
#  ('reste', 3),
#  ('vers', 3),
#  ('guerre', 3),
#  ('eux', 3),
#  ('sens', 3),
#  ('veut', 3),
#  ('ete', 3),
#  ('bonheur', 3),
#  ('celui', 2),
#  ('voeu', 2),
#  ('projet', 2),
#  ('européen', 2),
#  ('nouvelles', 2),
#  ('parfois', 2),
#  ('nouveaux', 2),
#  ('quoi', 2),
#  ('forte', 2),
#  ('forces', 2),
#  ('devoir', 2),
#  ('salariés', 2),
#  ('loi', 2),
#  ('demain', 2),
#  ('prendre', 2),
#  ('patrie', 2),
#  ('urgence', 2),
#  ('aucun', 2),
#  ('protéger', 2),
#  ('cet', 2),
#  ('malgré', 2),
#  ('paris', 2),
#  ('dernier', 2),
#  ('notamment', 2),
#  ('cinq', 2),
#  ('jusqu', 2),
#  ('histoire', 2),
#  ('sait', 2),
#  ('françaises', 2),
#  ('objectif', 2),
#  ('difficile', 2),
#  ('soyons', 2),
#  ('adapter', 2),
#  ('dialogue', 2),
#  ('grands', 2),
#  ('union', 2),
#  ('peuple', 2),
#  ('heureuse', 2),
#  ('voulu', 2),
#  ('possible', 2),
#  ('outre', 2),
#  ('nationale', 2),
#  ('peuples', 2),
#  ('enfin', 2),
#  ('chez', 2),
#  ('lois', 2),
#  ('pourtant', 2),
#  ('inquiétude', 2),
#  ('signal', 2),
#  ('général', 2),
#  ('gens', 2),
#  ('etats', 2),
#  ('intérêt', 2),
#  ('économique', 2),
#  ('meilleur', 2),
#  ('propositions', 2),
#  ('nations', 2),
#  ('aura', 2),
#  ('fin', 2),
#  ('abord', 2),
#  ('également', 2),
#  ('souvent', 2),
#  ('certains', 2),
#  ('nom', 2),
#  ('lutte', 2),
#  ('faisons', 2),
#  ('social', 2),
#  ('école', 2),
#  ('doivent', 2),
#  ('effort', 2),
#  ('cest', 2),
#  ('préserver', 2),
#  ('mondialisation', 2),
#  ('siècle', 2),
#  ('moment', 2),
#  ('exigence', 2),
#  ('esprit', 2),
#  ('activité', 2),
#  ('grande', 2),
#  ('allons', 2),
#  ('force', 2),
#  ('protection', 2),
#  ('nouveau', 2),
#  ('liberte', 2),
#  ('fraternite', 2),
#  ('etre', 2),
#  ('sante', 2),
#  ('meme', 2),
#  ('engagement', 1),
#  ('règles', 1),
#  ('indispensable', 1),
#  ('retrouver', 1),
#  ('continuerons', 1),
#  ('crois', 1),
#  ('grandes', 1),
#  ('vérité', 1),
#  ('colère', 1),
#  ('dignité', 1),
#  ('nombre', 1),
#  ('voulons', 1),
#  ('famille', 1),
#  ('profondément', 1),
#  ('décennie', 1),
#  ('unité', 1),
#  ('décisions', 1),
#  ('écologique', 1),
#  ('assurer', 1),
#  ('vies', 1),
#  ('épidémie', 1),
#  ('printemps', 1),
#  ('européenne', 1),
#  ('virus', 1),
#  ('demandé', 1),
#  ('compétitivité', 1),
#  ('compris', 1),
#  ('peur', 1),
#  ('stabilité', 1),
#  ('négociation', 1),
#  ('conférence', 1),
#  ('personnes', 1),
#  ('allais', 1),
#  ('planète', 1),
#  ('seront', 1),
#  ('attentats', 1),
#  ('parlement', 1),
#  ('adresse', 1),
#  ('surtout', 1),
#  ('santé', 1),
#  ('origines', 1),
#  ('capacité', 1),
#  ('acquis', 1),
#  ('doute', 1),
#  ('cause', 1),
#  ('mandat', 1),
#  ('avais', 1),
#  ('promis', 1),
#  ('faudra', 1),
#  ('inflation', 1),
#  ('condition', 1),
#  ('produire', 1),
#  ('quiconque', 1),
#  ('formation', 1),
#  ('marchés', 1),
#  ('ordre', 1),
#  ('travailleurs', 1),
#  ('départements', 1),
#  ('statut', 1),
#  ('revenons', 1),
#  ('supporter', 1),
#  ('territoires', 1),
#  ('dit', 1),
#  ('pendant', 1),
#  ('apportée', 1),
#  ('régionale', 1),
#  ('tolérance', 1),
#  ('gagne', 1),
#  ('parents', 1),
#  ('petite', 1),
#  ('rien', 1),
#  ('jeunesse', 1),
#  ('aimons', 1),
#  ('mission', 1),
#  ('demandez', 1),
#  ('cher', 1),
#  ('injustice', 1),
#  ('cinquième', 1),
#  ('étape', 1),
#  ('coûte', 1),
#  ('puissance', 1),
#  ('commence', 1),
#  ('courte', 1),
#  ('instant', 1),
#  ('grave', 1),
#  ('montré', 1),
#  ('sache', 1),
#  ('défense', 1),
#  ('devions', 1),
#  ('démocratie', 1),
#  ('vois', 1),
#  ('dangereuse', 1),
#  ('parviendra', 1),
#  ('vaut', 1),
#  ('inutile', 1),
#  ('unir', 1),
#  ('rendez', 1),
#  ('souhaitons', 1),
#  ('fraternité', 1),
#  ('sente', 1),
#  ('exprimer', 1),
#  ('développés', 1),
#  ('prêtons', 1),
#  ('strasbourg', 1),
#  ('me', 1),
#  ('risque', 1),
#  ('afin', 1),
#  ('attends', 1),
#  ('seule', 1),
#  ('ait', 1),
#  ('exemple', 1),
#  ('quatre', 1),
#  ('forme', 1),
#  ('varsovie', 1),
#  ('auront', 1),
#  ('millions', 1),
#  ('régnait', 1),
#  ('bosnie', 1),
#  ('camps', 1),
#  ('unies', 1),
#  ('puisque', 1),
#  ('communauté', 1),
#  ('sagesse', 1),
#  ('audace', 1),
#  ('cas', 1),
#  ('algérie', 1),
#  ('douze', 1),
#  ('continent', 1),
#  ('loin', 1),
#  ('soldats', 1),
#  ('exemples', 1),
#  ('souffrent', 1),
#  ('véritable', 1),
#  ('plan', 1),
#  ('prochain', 1),
#  ('montrer', 1),
#  ('pouvoirs', 1),
#  ('plein', 1),
#  ('initiatives', 1),
#  ('dépend', 1),
#  ('leçon', 1),
#  ('mettre', 1),
#  ('construire', 1),
#  ('reculer', 1),
#  ('autrement', 1),
#  ('capable', 1),
#  ('violence', 1),
#  ('apaisée', 1),
#  ('accueillante', 1),
#  ('nest', 1),
#  ('dentre', 1),
#  ('fais', 1),
#  ('dautres', 1),
#  ('dêtre', 1),
#  ('rassemblée', 1),
#  ('lon', 1),
#  ('créer', 1),
#  ('riches', 1),
#  ('comprendre', 1),
#  ('ainsi', 1),
#  ('courage', 1),
#  ('sachons', 1),
#  ('changer', 1),
#  ('savons', 1),
#  ('leuro', 1),
#  ('responsable', 1),
#  ('marche', 1),
#  ('ouvert', 1),
#  ('chance', 1),
#  ('chemin', 1),
#  ('parmi', 1),
#  ('hommes', 1),
#  ('part', 1),
#  ('mesurons', 1),
#  ('homme', 1),
#  ('réussirons', 1),
#  ('euro', 1),
#  ('cohésion', 1),
#  ('qualité', 1),
#  ('voulez', 1),
#  ('charge', 1),
#  ('trouver', 1),
#  ('particulière', 1),
#  ('épreuves', 1),
#  ('rassemblement', 1),
#  ('lucidité', 1),
#  ('responsabilité', 1),
#  ('était', 1),
#  ('donner', 1),
#  ('mobiliser', 1),
#  ('système', 1),
#  ('continuera', 1),
#  ('égalité', 1),
#  ('première', 1),
#  ('soutien', 1),
#  ('dynamisme', 1),
#  ('renforcer', 1),
#  ('poursuivre', 1),
#  ('partenaires', 1),
#  ('atout', 1),
#  ('innovation', 1),
#  ('métropole', 1),
#  ('ouvrir', 1),
#  ('enjeu', 1),
#  ('victimes', 1),
#  ('recherche', 1),
#  ('comportements', 1),
#  ('garantie', 1),
#  ('vis', 1),
#  ('changement', 1),
#  ('pris', 1),
#  ('rôle', 1),
#  ('sentiment', 1),
#  ('civilisation', 1),
#  ('attendent', 1),
#  ('vieux', 1),
#  ('organisation', 1),
#  ('dépenses', 1),
#  ('fiscalité', 1),
#  ('financière', 1),
#  ('fut', 1),
#  ('serait', 1),
#  ('passé', 1),
#  ('assez', 1),
#  ('ferai', 1),
#  ('façon', 1),
#  ('peine', 1),
#  ('économie', 1),
#  ('années', 1),
#  ('finance', 1),
#  ('question', 1),
#  ('défis', 1),
#  ('conséquences', 1),
#  ('pouvons', 1),
#  ('francaise', 1),
#  ('voudrais', 1),
#  ('problemes', 1),
#  ('societe', 1),
#  ('certaines', 1),
#  ('categories', 1),
#  ('adresser', 1),
#  ('mains', 1),
#  ('rayonnement', 1),
#  ('economie', 1),
#  ('adressent', 1),
#  ('grandeur', 1),
#  ('dimension', 1),
#  ('nord', 1),
#  ('traverse', 1),
#  ('cadre', 1),
#  ('moderne', 1),
#  ('giscard', 1),
#  ('dis', 1),
#  ('difficultes', 1),
#  ('pensons', 1),
#  ('activite', 1),
#  ('lorsqu', 1),
#  ('competition', 1),
#  ('surmonter', 1),
#  ('vrai', 1),
#  ('gars', 1),
#  ('memes', 1),
#  ('toit', 1),
#  ('voulaient', 1),
#  ('vient', 1),
#  ('personnage', 1),
#  ('succes', 1),
#  ('trois', 1),
#  ('heureux', 1),
#  ('concours', 1),
#  ('regions', 1),
#  ('annees', 1),
#  ('soient', 1),
#  ('republique', 1),
#  ('petrole', 1),
#  ('augmente', 1),
#  ('achat', 1),
#  ('amis', 1),
#  ('periode', 1),
#  ('choc', 1),
#  ('soiree', 1),
#  ('president', 1),
#  ('inegalites', 1),
#  ('telles', 1),
#  ('libertés', 1),
#  ('choses', 1),
#  ('signes', 1),
#  ('indépendance', 1),
#  ('compter', 1),
#  ('rang', 1)]

# %%
# If more than half of the comedians have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 6]
add_stop_words
# Out:
# ['france',
#  'année',
#  'compatriotes',
#  'pays',
#  'chers',
#  'monde',
#  'sera',
#  'europe',
#  'bien',
#  'français',
#  'vie',
#  'bonne',
#  'république',
#  'travail',
#  'soir',
#  'avenir',
#  'autres',
#  'vive',
#  'paix',
#  'voeux',
#  'veux',
#  'nouvelle',
#  'politique',
#  'gouvernement',
#  'dire',
#  'contre',
#  'mieux',
#  'nation',
#  'mois',
#  'temps',
#  'faut',
#  'leurs',
#  'celle',
#  'ensemble',
#  'confiance',
#  'crise',
#  'emploi',
#  'sécurité',
#  'dont',
#  'place']

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer

# Read in cleaned data
data_clean = pd.read_pickle('data_clean_fr.pkl')

# Add new stop words
#stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)
fsw = open('french_sw.txt', encoding='utf8').read().split('\n')
stop_words = fsw + add_stop_words
# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.transcript)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.index

# Pickle it for later use
import pickle
pickle.dump(cv, open("cv_stop_fr.pkl", "wb"))
data_stop.to_pickle("dtm_stop_fr.pkl")

# %%
# Let's make some word clouds!
# Terminal / Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

full_names = ['Ali Wong', 'Anthony Jeselnik', 'Bill Burr', 'Bo Burnham', 'Dave Chappelle', 'Hasan Minhaj',
              'Jim Jefferies', 'Joe Rogan', 'John Mulaney', 'Louis C.K.', 'Mike Birbiglia', 'Ricky Gervais']
data_fr = pickle.load(open('data_fr.pkl','rb'))
full_names = data_fr.keys()
print(full_names)

# Create subplots for each comedian
for index, comedian in enumerate(data.columns):
    print(index, comedian)
    wc.generate(data_clean.transcript[comedian])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(full_names[index])
    
plt.show()
# Out:
# dict_keys(['Emmanuel Macron 2020', 'Emmanuel Macron 2019', 'Emmanuel Macron 2018', 'Emmanuel Macron 2017', 'François Hollande 2016', 'François Hollande 2015', 'François Hollande 2014', 'François Hollande 2012', 'Nicolas Sarkozy 2011', 'Nicolas Sarkozy 2010', 'Nicolas Sarkozy 2009', 'Nicolas Sarkozy 2007', 'Jacques Chirac 2006', 'Jacques Chirac 2005', 'Jacques Chirac 2004', 'Jacques Chirac 2003', 'Jacques Chirac 2002', 'Jacques Chirac 2001', 'Jacques Chirac 1999', 'Jacques Chirac 1998', 'Jacques Chirac 1997', 'Jacques Chirac 1996', 'Jacques Chirac 1995', 'François Mitterrand 1994', 'François Mitterrand 1993', 'François Mitterrand 1992', 'François Mitterrand 1991', 'François Mitterrand 1990', 'François Mitterrand 1989', 'François Mitterrand 1988', 'François Mitterrand 1987', 'François Mitterrand 1986', 'François Mitterrand 1985', 'François Mitterrand 1984', 'François Mitterrand 1983', 'François Mitterrand 1982', 'François Mitterrand 1981', 'Valéry Giscard d’Estaing 1980', 'Valéry Giscard d’Estaing 1979', 'Valéry Giscard d’Estaing 1978', 'Valéry Giscard d’Estaing 1977', 'Valéry Giscard d’Estaing 1975', 'Valéry Giscard d’Estaing 1974'])
# 0 Emmanuel Macron 2017
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26520/2143986890.py in <module>
#      18     plt.imshow(wc, interpolation="bilinear")
#      19     plt.axis("off")
# ---> 20     plt.title(full_names[index])
#      21
#      22 plt.show()
#
# TypeError: 'dict_keys' object is not subscriptable

# %% [markdown]
# ### Findings

# %% [markdown]
# * Ali Wong says the s-word a lot and talks about her husband. I guess that's funny to me.
# * A lot of people use the F-word. Let's dig into that later.

# %% [markdown]
# ## Number of Words

# %% [markdown]
# ### Analysis

# %%
# Find the number of unique words that each comedian uses

# Identify the non-zero items in the document-term matrix, meaning that the word occurs at least once
unique_list = []
for comedian in data.columns:
    uniques = data[comedian].to_numpy().nonzero()[0].size
    unique_list.append(uniques)

# Create a new dataframe that contains this unique word count
data_words = pd.DataFrame(list(zip(full_names, unique_list)), columns=['comedian', 'unique_words'])
data_unique_sort = data_words.sort_values(by='unique_words')
data_unique_sort
# Out:
#                          comedian  unique_words
# 10           Nicolas Sarkozy 2009           160
# 11           Nicolas Sarkozy 2007           195
# 39  Valéry Giscard d’Estaing 1978           208
# 13            Jacques Chirac 2005           235
# 12            Jacques Chirac 2006           240
# 40  Valéry Giscard d’Estaing 1977           241
# 38  Valéry Giscard d’Estaing 1979           255
# 14            Jacques Chirac 2004           255
# 42  Valéry Giscard d’Estaing 1974           287
# 31       François Mitterrand 1986           320
# 17            Jacques Chirac 2001           326
# 18            Jacques Chirac 1999           326
# 24       François Mitterrand 1993           332
# 16            Jacques Chirac 2002           337
# 15            Jacques Chirac 2003           343
# 41  Valéry Giscard d’Estaing 1975           345
# 28       François Mitterrand 1989           353
# 32       François Mitterrand 1985           357
# 37  Valéry Giscard d’Estaing 1980           359
# 20            Jacques Chirac 1997           362
# 9            Nicolas Sarkozy 2010           377
# 25       François Mitterrand 1992           379
# 19            Jacques Chirac 1998           383
# 29       François Mitterrand 1988           385
# 36       François Mitterrand 1981           393
# 21            Jacques Chirac 1996           396
# 23       François Mitterrand 1994           406
# 4          François Hollande 2016           408
# 35       François Mitterrand 1982           411
# 30       François Mitterrand 1987           413
# 34       François Mitterrand 1983           415
# 8            Nicolas Sarkozy 2011           417
# 33       François Mitterrand 1984           417
# 27       François Mitterrand 1990           428
# 26       François Mitterrand 1991           446
# 22            Jacques Chirac 1995           459
# 5          François Hollande 2015           470
# 6          François Hollande 2014           492
# 7          François Hollande 2012           493
# 0            Emmanuel Macron 2020           573
# 3            Emmanuel Macron 2017           669
# 1            Emmanuel Macron 2019           680
# 2            Emmanuel Macron 2018           732

# %%
# Calculate the words per minute of each comedian

# Find the total number of words that a comedian uses
total_list = []
for comedian in data.columns:
    totals = sum(data[comedian])
    total_list.append(totals)
    
# Comedy special run times from IMDB, in minutes
run_times = [60, 59, 80, 60, 67, 73, 77, 63, 62, 58, 76, 79]

# Let's add some columns to our dataframe
data_words['total_words'] = total_list
data_words['run_times'] = run_times
data_words['words_per_minute'] = data_words['total_words'] / data_words['run_times']

# Sort the dataframe by words per minute to see who talks the slowest and fastest
data_wpm_sort = data_words.sort_values(by='words_per_minute')
data_wpm_sort

# %%
# Let's plot our findings
import numpy as np

y_pos = np.arange(len(data_words))

plt.subplot(1, 2, 1)
plt.barh(y_pos, data_unique_sort.unique_words, align='center')
plt.yticks(y_pos, data_unique_sort.comedian)
plt.title('Number of Unique Words', fontsize=20)

plt.subplot(1, 2, 2)
plt.barh(y_pos, data_wpm_sort.words_per_minute, align='center')
plt.yticks(y_pos, data_wpm_sort.comedian)
plt.title('Number of Words Per Minute', fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Vocabulary**
#    * Ricky Gervais (British comedy) and Bill Burr (podcast host) use a lot of words in their comedy
#    * Louis C.K. (self-depricating comedy) and Anthony Jeselnik (dark humor) have a smaller vocabulary
#
#
# * **Talking Speed**
#    * Joe Rogan (blue comedy) and Bill Burr (podcast host) talk fast
#    * Bo Burnham (musical comedy) and Anthony Jeselnik (dark humor) talk slow
#
# Ali Wong is somewhere in the middle in both cases. Nothing too interesting here.

# %% [markdown]
# ## Amount of Profanity

# %% [markdown]
# ### Analysis

# %%
# Earlier I said we'd revisit profanity. Let's take a look at the most common words again.
Counter(words).most_common()

# %%
# Let's isolate just these bad words
data_bad_words = data.transpose()[['fucking', 'fuck', 'shit']]
data_profanity = pd.concat([data_bad_words.fucking + data_bad_words.fuck, data_bad_words.shit], axis=1)
data_profanity.columns = ['f_word', 's_word']
data_profanity

# %%
# Let's create a scatter plot of our findings
plt.rcParams['figure.figsize'] = [10, 8]

for i, comedian in enumerate(data_profanity.index):
    x = data_profanity.f_word.loc[comedian]
    y = data_profanity.s_word.loc[comedian]
    plt.scatter(x, y, color='blue')
    plt.text(x+1.5, y+0.5, full_names[i], fontsize=10)
    plt.xlim(-5, 155) 
    
plt.title('Number of Bad Words Used in Routine', fontsize=20)
plt.xlabel('Number of F Bombs', fontsize=15)
plt.ylabel('Number of S Words', fontsize=15)

plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Averaging 2 F-Bombs Per Minute!** - I don't like too much swearing, especially the f-word, which is probably why I've never heard of Bill Bur, Joe Rogan and Jim Jefferies.
# * **Clean Humor** - It looks like profanity might be a good predictor of the type of comedy I like. Besides Ali Wong, my two other favorite comedians in this group are John Mulaney and Mike Birbiglia.

# %% [markdown]
# ## Side Note

# %% [markdown]
# What was our goal for the EDA portion of our journey? **To be able to take an initial look at our data and see if the results of some basic analysis made sense.**
#
# My conclusion - yes, it does, for a first pass. There are definitely some things that could be better cleaned up, such as adding more stop words or including bi-grams. But we can save that for another day. The results, especially the profanity findings, are interesting and make general sense, so we're going to move on.
#
# As a reminder, the data science process is an interative one. It's better to see some non-perfect but acceptable results to help you quickly decide whether your project is a dud or not, instead of having analysis paralysis and never delivering anything.
#
# **Alice's data science (and life) motto: Let go of perfectionism!**

# %% [markdown]
# ## Additional Exercises

# %% [markdown]
# 1. What other word counts do you think would be interesting to compare instead of the f-word and s-word? Create a scatter plot comparing them.
